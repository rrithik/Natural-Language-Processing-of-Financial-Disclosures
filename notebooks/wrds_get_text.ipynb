# %%
# IMPORTANT:
# This code requires the WRDS-hosted Jupyter environment to run.
# It will NOT work on a local machine because it relies on WRDS internal paths and direct filesystem
# links: https://wrds-jupyter.wharton.upenn.edu/
# the only file you need to provide is "practicelist.csv" which contains a column "path" with SEC public paths.

import pandas as pd # type: ignore[import-untyped]
import os
import wrds # type: ignore[import-not-found]

# 1. Connect
db = wrds.Connection()


# 2. Load your public SEC paths
df = pd.read_csv("practicelist.csv")   # contains column: path

print("Mapping SEC public paths → WRDS internal paths...\n")


# 3. Query ALL mappings at once
public_paths_tuple = tuple(df["path"].unique())

query = f"""
    SELECT fname, wrdsfname
    FROM wrdssec.wrds_forms
    WHERE fname IN {public_paths_tuple}
"""

mapping = db.raw_sql(query)
df = df.merge(mapping, how="left", left_on="path", right_on="fname")



# Preview the top 200 rows. It's just for display.
# The script will still process every row in the dataset.

print("Found matches:")
print(df.head(200)) 


# 4. Extract the raw text using WRDS internal paths
all_docs = []

print("\nExtracting text from WRDS filesystem...\n")

for _, row in df.iterrows():
    wrdsfname = row["wrdsfname"]

    if pd.isna(wrdsfname):
        print("NO MATCH:", row["path"])
        continue 

    file_path = f"/wrds/sec/warchives/{wrdsfname}"

    if not os.path.exists(file_path):
        print("MISSING:", file_path)
        continue

    try:
        with open(file_path, "r", errors="ignore") as f:
            text = f.read()

        all_docs.append(text)
        print("OK:", file_path)

    except Exception as e:
        print("FAILED:", file_path, e)

        
# 5. Save big text file
print("\nSaving all text to wrds_text_data.txt...")

with open("wrds_text_data.txt", "w", errors="ignore") as out:
    for text in all_docs:
        out.write(text)
        out.write("\n\n" + "="*80 + "\n\n")

print("Done! File saved as wrds_text_data.txt")
# Out:
# Loading library list...
# Done
# Mapping SEC public paths → WRDS internal paths...
#
# Found matches:
#                                         path  \
# 0   edgar/data/2488/0001193125-13-001042.txt
# 1   edgar/data/2488/0001193125-13-019330.txt
# 2   edgar/data/2488/0001193125-13-019330.txt
# 3   edgar/data/2488/0001193125-13-019330.txt
# 4   edgar/data/2488/0001193125-13-052006.txt
# ..                                       ...
# 95  edgar/data/3545/0000891092-13-000599.txt
# 96  edgar/data/3545/0000891092-13-000732.txt
# 97  edgar/data/3545/0000891092-13-001075.txt
# 98  edgar/data/3545/0000891092-13-001598.txt
# 99  edgar/data/3545/0000891092-13-002256.txt
#
#                                        fname  \
# 0   edgar/data/2488/0001193125-13-001042.txt
# 1   edgar/data/2488/0001193125-13-019330.txt
# 2   edgar/data/2488/0001193125-13-019330.txt
# 3   edgar/data/2488/0001193125-13-019330.txt
# 4   edgar/data/2488/0001193125-13-052006.txt
# ..                                       ...
# 95  edgar/data/3545/0000891092-13-000599.txt
# 96  edgar/data/3545/0000891092-13-000732.txt
# 97  edgar/data/3545/0000891092-13-001075.txt
# 98  edgar/data/3545/0000891092-13-001598.txt
# 99  edgar/data/3545/0000891092-13-002256.txt
#
#                                wrdsfname
# 0   000000/2488/0001193125-13-001042.txt
# 1   000000/2488/0001193125-13-019330.txt
# 2   000000/2488/0001193125-13-019330.txt
# 3   000000/2488/0001193125-13-019330.txt
# 4   000000/2488/0001193125-13-052006.txt
# ..                                   ...
# 95  000000/3545/0000891092-13-000599.txt
# 96  000000/3545/0000891092-13-000732.txt
# 97  000000/3545/0000891092-13-001075.txt
# 98  000000/3545/0000891092-13-001598.txt
# 99  000000/3545/0000891092-13-002256.txt
#
# [100 rows x 3 columns]
#
# Extracting text from WRDS filesystem...
#
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-001042.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-019330.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-019330.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-019330.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-052006.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-077035.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-102285.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-126831.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-160817.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-160817.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-231461.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-231461.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-241753.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-256167.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-259723.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-289571.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-294361.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-294361.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-295631.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-402500.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-402500.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-436767.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-13-436767.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-016032.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-016032.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-045586.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-059941.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-061268.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-069925.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-069925.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-091714.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-108119.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-107296.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-126113.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-147719.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-147719.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-197165.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-221063.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-222915.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-234226.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-237844.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-237844.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-244560.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-244560.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-271677.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-271677.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-306696.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-341850.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-358960.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-366751.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-371185.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-373863.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-373863.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-373863.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-437727.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-445379.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-14-454203.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-008247.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-014914.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-014914.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-051437.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-133355.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-133355.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-133355.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-169207.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-15-169201.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000035.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000035.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000040.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000040.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000047.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000055.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000062.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000062.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000062.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-15-000088.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000102.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000102.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000118.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000118.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000127.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000127.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000141.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000168.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-16-639147.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000210.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000210.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000247.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000247.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-16-709676.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-16-709676.txt
# OK: /wrds/sec/warchives/000000/2488/0001193125-16-709676.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000258.txt
# OK: /wrds/sec/warchives/000000/2488/0000002488-16-000258.txt
# OK: /wrds/sec/warchives/000000/3545/0000891092-13-000228.txt
# OK: /wrds/sec/warchives/000000/3545/0000891092-13-000599.txt
# OK: /wrds/sec/warchives/000000/3545/0000891092-13-000732.txt
# OK: /wrds/sec/warchives/000000/3545/0000891092-13-001075.txt
# OK: /wrds/sec/warchives/000000/3545/0000891092-13-001598.txt
# OK: /wrds/sec/warchives/000000/3545/0000891092-13-002256.txt
#
# Saving all text to wrds_text_data2.txt...
# Done! File saved as wrds_text_data2.txt
